# %%
import tensorflow as tf
from tensorflow.keras import layers,models,datasets
import matplotlib.pyplot as plt

# %%
(train_images,train_labels),(test_images, test_labels) = datasets.fashion_mnist.load_data()
train_images,test_images = train_images/255.0, test_images/255.0

# %%
#model sieci głębokiej
model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128,activation='relu'),
    layers.Dense(256,activation='relu'),
    layers.Dense(512,activation='relu'),
    layers.Dense(512,activation='relu'),
    layers.Dense(256,activation='relu'),
    layers.Dense(128,activation='relu'),
    layers.Dense(10,activation='softmax'),
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(train_images,train_labels,epochs=10,validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.5260 - accuracy: 0.8091 - val_loss: 0.4601 - val_accuracy: 0.8393
# Epoch 2/10
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.3961 - accuracy: 0.8579 - val_loss: 0.3932 - val_accuracy: 0.8594
# Epoch 3/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3603 - accuracy: 0.8716 - val_loss: 0.4505 - val_accuracy: 0.8390
# Epoch 4/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.3385 - accuracy: 0.8780 - val_loss: 0.3792 - val_accuracy: 0.8660
# Epoch 5/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.3160 - accuracy: 0.8847 - val_loss: 0.4010 - val_accuracy: 0.8608
# Epoch 6/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3008 - accuracy: 0.8903 - val_loss: 0.4118 - val_accuracy: 0.8609
# Epoch 7/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2913 - accuracy: 0.8928 - val_loss: 0.3717 - val_accuracy: 0.8700
# Epoch 8/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2789 - accuracy: 0.8986 - val_loss: 0.3517 - val_accuracy: 0.8794
# Epoch 9/10
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.2700 - accuracy: 0.8997 - val_loss: 0.3514 - val_accuracy: 0.8826
# Epoch 10/10
# 1875/1875 [==============================] - 85s 46ms/step - loss: 0.2605 - accuracy: 0.9045 - val_loss: 0.3632 - val_accuracy: 0.8814

# %%
test_loss, test_acc = model.evaluate(test_images,test_labels)
print(f'dokładność: {test_acc}, strata: {test_loss}')
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3632 - accuracy: 0.8814
# dokładność: 0.8813999891281128, strata: 0.3631983697414398

# %%
predictions = model.predict(test_images)

first_image_index = 0
predicted_class = tf.argmax(predictions[first_image_index]).numpy()
print(f'odszukana klasa obrazu: {predicted_class}')
print(f'klasa porównawcza: {test_labels[first_image_index]}')
# Out:
# 313/313 [==============================] - 1s 2ms/step
# odszukana klasa obrazu: 9
# klasa porównawcza: 9
